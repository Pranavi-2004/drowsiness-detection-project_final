# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout,Input,Flatten,Dense,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator  # Data Augumentation

# %%
tf.test.is_gpu_available()
# Out:
# False

# %%
batchsize=8

# %%
train_datagen= ImageDataGenerator(rescale=1./255, rotation_range=0.2,shear_range=0.2,
    zoom_range=0.2,width_shift_range=0.2,
    height_shift_range=0.2, validation_split=0.2)

train_data= train_datagen.flow_from_directory(r'C:\Users\B Pranavi\.cache\kagglehub\datasets\imadeddinedjerarda\mrl-eye-dataset\versions\1\mrleyedataset\train_data',
                                target_size=(80,80),batch_size=batchsize,class_mode='categorical',subset='training' )

validation_data= train_datagen.flow_from_directory(r'C:\Users\B Pranavi\.cache\kagglehub\datasets\imadeddinedjerarda\mrl-eye-dataset\versions\1\mrleyedataset\train_data',
                                target_size=(80,80),batch_size=batchsize,class_mode='categorical', subset='validation')
# Out:
# Found 50233 images belonging to 2 classes.
# Found 12557 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

test_data = test_datagen.flow_from_directory(r'C:\Users\B Pranavi\.cache\kagglehub\datasets\imadeddinedjerarda\mrl-eye-dataset\versions\1\mrleyedataset\test_data',
                                target_size=(80,80),batch_size=batchsize,class_mode='categorical')
# Out:
# Found 20671 images belonging to 2 classes.

# %%
bmodel = InceptionV3(include_top=False, weights='imagenet', input_tensor=Input(shape=(80,80,3)))
hmodel = bmodel.output
hmodel = Flatten()(hmodel)
hmodel = Dense(64, activation='relu')(hmodel)
hmodel = Dropout(0.5)(hmodel)
hmodel = Dense(2,activation= 'softmax')(hmodel)

model = Model(inputs=bmodel.input, outputs= hmodel)
for layer in bmodel.layers:
    layer.trainable = False

# %%
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 80, 80, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_282 (Conv2D) │ (None, 39, 39,    │        864 │ input_layer_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 39, 39,    │         96 │ conv2d_282[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping, ReduceLROnPlateau

# %%
checkpoint = ModelCheckpoint(r'D:\Python37\Projects\iNeuron Intership Projects\CV_Driver_Drowsiness_Detection\models\model.h5',
                            monitor='val_loss',save_best_only=True,verbose=3)

earlystop = EarlyStopping(monitor = 'val_loss', patience=7, verbose= 3, restore_best_weights=True)

learning_rate = ReduceLROnPlateau(monitor= 'val_loss', patience=3, verbose= 3, )

callbacks=[checkpoint,earlystop,learning_rate]

# %%
# Model Evaluation
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(
    train_data,
    steps_per_epoch=train_data.samples // batchsize,
    validation_data=validation_data,
    validation_steps=validation_data.samples // batchsize,
    callbacks=callbacks,
    epochs=2
)
# Out:
# Epoch 1/2
# c:\Users\B Pranavi\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_945']
# Received: inputs=Tensor(shape=(None, 80, 80, 3))
#   warnings.warn(msg)
# 6279/6279 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9196 - loss: 0.2074
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 4
#       1 # Model Evaluation
#       2 model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])
# ----> 4 model.fit(
#       5     train_data,
#       6     steps_per_epoch=train_data.samples // batchsize,
#       7     validation_data=validation_data,
#       8     validation_steps=validation_data.samples // batchsize,
#       9     callbacks=callbacks,
#      10     epochs=2
#      11 )
#
# ...

# %%
loss_tr, acc_tr = model.evaluate(train_data)
print("Training Accuracy:", acc_tr)
print("Training Loss:", loss_tr)
# Out:
# 6280/6280 ━━━━━━━━━━━━━━━━━━━━ 322s 51ms/step - accuracy: 0.9512 - loss: 0.1242
# Training Accuracy: 0.9511476755142212
# Training Loss: 0.12509237229824066

# %%
loss_vr, acc_vr = model.evaluate(validation_data)
print(acc_vr)
print(loss_vr)
# Out:
# 1570/1570 ━━━━━━━━━━━━━━━━━━━━ 53s 34ms/step - accuracy: 0.9168 - loss: 0.2227
# 0.9155052900314331
# 0.21690522134304047

# %%
loss_test, acc_test = model.evaluate(test_data)
print(acc_test)
print(loss_test)
# Out:
# 2584/2584 ━━━━━━━━━━━━━━━━━━━━ 225s 87ms/step - accuracy: 0.8939 - loss: 0.2995
# 0.8963765501976013
# 0.29482752084732056

# %%
model.save(r"C:\Users\B Pranavi\Auproject\Driver-Drowsiness-Detection-using-Deep-Learning\models\model.keras")
